# %% [markdown]
# ### Content : scripts for world map with stations and covariate domains

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib import cm
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import ScalarFormatter
from matplotlib.patches import PathPatch
from matplotlib.ticker import FormatStrFormatter
from matplotlib.path import Path
import matplotlib.patches as patches
import matplotlib.font_manager as fm
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %% [markdown]
# ### Figure folder

# %%
dirout= "./figures/"

# %% [markdown]
# ### some parameters for text

# %%
plt.rcParams.update({
    'font.size': 15,
    'axes.labelsize': 'large',
    'axes.titlesize': 'large',
    'legend.fontsize': 'large',
    'lines.linewidth': 2,
    'figure.dpi': 100
})

rc('text', usetex=True) # LateX

# %% [markdown]
# ### PLOT

# %%
# --- list of stations [lon, lat] ---
liste_station = [
    [-52.365333,4.822333],
    [-54.028333,3.640167],
    [-51.804667,3.890667],
    [-54.031667,5.485500], 
    [-61.516333,16.264000],
    [-62.8521,17.9015],
    [-60.995667,14.595333],
    [55.528667,-20.892167],
    [45.2828,-12.8055],
    [54.5206,-15.8876],
    [164.284167,-20.558667],
    [166.222333,-22.017333],
    [166.4528333,-22.276000],
    [167.241167,-20.777667],
    [-176.1941,-13.2398],
    [-178.121,-14.3078],
    [-149.614333,-17.555167],
    [-139.035667,-9.806000],
    [-134.965333,-23.130167],
    [-144.334833,-27.618333],
    [-145.025167,-14.456833]
]

#colors per basin
colors=["purple","purple","purple","purple",
       "mediumblue","mediumblue","mediumblue","gold","gold","gold",
       "green","green","green","green","green","green",
       "red","red","red","red","red"]


projection = ccrs.Robinson(central_longitude=-60)

fig = plt.figure(figsize=(14, 7), dpi=300)
ax = plt.axes(projection=projection)

# to displat the whole globe
ax.set_global()

# background
ax.add_feature(cfeature.LAND, facecolor='beige')
ax.add_feature(cfeature.OCEAN, facecolor='lightskyblue',alpha=0.4)
ax.add_feature(cfeature.RIVERS)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)

# grid parameters
gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 15}
gl.ylabel_style = {'size': 15}


# PLOT
lons, lats = zip(*liste_station)
ax.scatter(
    lons, lats,
    color=colors,
    s=160,
    marker="*",edgecolor='k',
    transform=ccrs.PlateCarree(),
    zorder=5
)

# to write the station names
for station in all_stations:
    
    if station == "Gillot":
        
        ax.text(x=51.528667,y=-28.892167,s=station,
            fontsize=15,transform=ccrs.PlateCarree())
        
    if station == "Pamandzi":
        
        ax.text(x=43.528667,y=-8.892167,s=station,
            fontsize=15,transform=ccrs.PlateCarree())
        
    if station == "Tromelin":
        
        ax.text(x=59.528667,y=-17.892167,s=station,
            fontsize=15,transform=ccrs.PlateCarree())
        
    if station == "Hiva-Oa":
        
        ax.text(x=-135.035667,y=-5.806000,s=station,
            fontsize=15,transform=ccrs.PlateCarree())
        
    if station == "Rapa":
        
        ax.text(x=-164.334833,y=-28.618333,s=station,
            fontsize=15,transform=ccrs.PlateCarree())
        
    if station == "Mangareva":
        
        ax.text(x=-130.965333,y=-23.130167,s=station,
            fontsize=15,transform=ccrs.PlateCarree())
        
    if station == "Takaroa":
        
        ax.text(x=-170.025167,y=-10.456833,s=station,
            fontsize=15,transform=ccrs.PlateCarree())
        
    if station == "Faaa":
        
        ax.text(x=-168.614333,y=-19.555167,s=station,
            fontsize=15,transform=ccrs.PlateCarree())

#saving
fig.savefig(dirout+"world_map.png")
fig.savefig(dirout+"world_map.svg")

# %%
# --- list of stations [lon, lat] ---
liste_station = [
    [-52.365333,4.822333],
    [-54.028333,3.640167],
    [-51.804667,3.890667],
    [-54.031667,5.485500], 
    [-61.516333,16.264000],
    [-62.8521,17.9015],
    [-60.995667,14.595333],
    [55.528667,-20.892167],
    [45.2828,-12.8055],
    [54.5206,-15.8876],
    [164.284167,-20.558667],
    [166.222333,-22.017333],
    [166.4528333,-22.276000],
    [167.241167,-20.777667],
    [-176.1941,-13.2398],
    [-178.121,-14.3078],
    [-149.614333,-17.555167],
    [-139.035667,-9.806000],
    [-134.965333,-23.130167],
    [-144.334833,-27.618333],
    [-145.025167,-14.456833]
]

#colors of stations
colors=["purple","purple","purple","purple",
       "mediumblue","mediumblue","mediumblue","gold","gold","gold",
       "green","green","green","green","green","green",
       "red","red","red","red","red"]

projection = ccrs.Robinson(central_longitude=-60)

fig = plt.figure(figsize=(14, 7), dpi=300)
ax = plt.axes(projection=projection)

# to display the whole globe
ax.set_global()

# background
ax.add_feature(cfeature.LAND, facecolor='beige')
ax.add_feature(cfeature.OCEAN, facecolor='lightskyblue',alpha=0.4)
ax.add_feature(cfeature.RIVERS)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)

# grid parameters
gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 15}
gl.ylabel_style = {'size': 15}

#limits of covariate domains
lon_min_pacific,lon_max_pacific,lat_min_pacific,lat_max_pacific=(155,230,-30,0)
lon_min_atlantic,lon_max_atlantic,lat_min_atlantic,lat_max_atlantic=(-80,-30,-20,20)
lon_min_indian,lon_max_indian,lat_min_indian,lat_max_indian=(30,80,-35,-5)

#Plot domains
p_pacific=patches.Rectangle((lon_min_pacific,lat_min_pacific),height=abs(lat_max_pacific-lat_min_pacific),width=abs(lon_max_pacific-lon_min_pacific),linewidth=2, linestyle='--',ec='k',fc='lightgrey',alpha=0.5,transform=ccrs.PlateCarree())
ax.add_artist(p_pacific)

p_atlantic=patches.Rectangle((lon_min_atlantic,lat_min_atlantic),height=abs(lat_max_atlantic-lat_min_atlantic),width=abs(lon_max_atlantic-lon_min_atlantic),linewidth=2, linestyle='--',ec='k',fc='lightgrey',alpha=0.5,transform=ccrs.PlateCarree())
ax.add_artist(p_atlantic)

p_indian=patches.Rectangle((lon_min_indian,lat_min_indian),height=abs(lat_max_indian-lat_min_indian),width=abs(lon_max_indian-lon_min_indian),linewidth=2, linestyle='--',ec='k',fc='lightgrey',alpha=0.5,transform=ccrs.PlateCarree())
ax.add_artist(p_indian)


# Plot stations
lons, lats = zip(*liste_station)
ax.scatter(
    lons, lats,
    color=colors,
    s=160,
    marker="*",edgecolor='k',
    transform=ccrs.PlateCarree(),
    zorder=5
)

#saving
fig.savefig(dirout+"world_map_with_guiana_and_covar.png")
fig.savefig(dirout+"world_map_with_guiana_and_covar.svg")
